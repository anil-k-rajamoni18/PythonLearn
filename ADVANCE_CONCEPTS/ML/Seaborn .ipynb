# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\akraj\anaconda3\lib\site-packages (0.12.2)
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\akraj\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\akraj\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\akraj\anaconda3\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akraj\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akraj\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\akraj\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\akraj\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 217.9 kB/s eta 0:00:02
#    -------- ------------------------------ 61.4/294.9 kB 328.2 kB/s eta 0:00:01
#    --------------------- ---------------- 163.8/294.9 kB 701.4 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

print(sns.__version__) # dunder variables __name__
# Out:
# 0.13.2

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_axis = np.arange(-20, 20, 0.01)
x_axis
mean = statistics.mean(x_axis)
mean
sd = statistics.stdev(x_axis)
sd
len(norm.pdf(x_axis, mean, sd))
norm.pdf(x_axis, mean, sd)
# Out:
# array([0.00771673, 0.0077283 , 0.00773989, ..., 0.00773989, 0.0077283 ,
#        0.00771673])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-20, 20, 0.01)

# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)

plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %%
sns.set(style = 'darkgrid')

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_base', '_compat', '_core', '_docstrings', '_orig_rc_params', '_statistics', '_stats', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'displot', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'ecdfplot', 'external', 'get_data_home', 'get_dataset_names', 'heatmap', 'histplot', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'matrix', 'miscplot', 'move_legend', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'palplot', 'plotting_context', 'pointplot', 'rcmod', 'regplot', 'regression', 'relational', 'relplot', 'reset_defaults', 'reset_orig', 'residplot', 'rugplot', 'saturate', 'scatterplot', 'set', 'set_color_codes', 'set_context', 'set_hls_values', 'set_palette', 'set_style', 'set_theme', 'stripplot', 'swarmplot', 'utils', 'violinplot', 'widgets', 'xkcd_palette', 'xkcd_rgb']

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
tips['tip'].plot()
# Out:
# <Axes: >

# %%
tips['tip'].min()
# Out:
# 1.0

# %%
tips['tip'].max()
# Out:
# 10.0

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)

# %%
tips["total_bill"].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', style = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips,hue = 'smoker', style = 'time', size = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size')

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))

# %%
df
# Out:
#      time     value
# 0       0  0.136059
# 1       1 -1.750921
# 2       2 -1.586250
# 3       3 -0.932944
# 4       4 -0.048856
# ..    ...       ...
# 495   495  5.722440
# 496   496  6.002248
# 497   497  8.408397
# 498   498  7.638268
# 499   499  7.426026
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
df = pd.DataFrame(randn(500, 2).cumsum(axis = 0), columns = ['time', 'value'])

# %%
df.head()
# Out:
#        time     value
# 0 -0.720076  0.570635
# 1 -0.854269  0.115397
# 2 -0.697350  0.182839
# 3 -1.031894 -0.985833
# 4 -0.972190 -0.744525

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
fmri.isnull().sum()
# Out:
# subject      0
# timepoint    0
# event        0
# region       0
# signal       0
# dtype: int64

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')
# Out:
# C:\Users\akraj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator = None, kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)

# %%
fmri.head()

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', style = 'event', kind = 'line', data = fmri)

# %%
df = pd.DataFrame(dict(time = pd.date_range('2019-06-02', periods = 500), value = randn(500).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2019-06-02 -0.023378
# 1 2019-06-03  0.642034
# 2 2019-06-04  0.115944
# 3 2019-06-05  0.774914
# 4 2019-06-06  1.629209

# %%
g = sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips, col_wrap=3, height=3)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style='bars')
# Out:
# C:\Users\akraj\AppData\Local\Temp\ipykernel_9400\1806847177.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style='bars')
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = iris['sepal_length'], y = iris['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#catplot()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.set(style = 'darkgrid')
data = sns.catplot(x = 'day', y = 'total_bill', data = tips)
data.savefig("demo1.png")

# %%
sns.catplot(y = 'day', x = 'total_bill', data = tips)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False)

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'swarm', hue = 'size')
# Out:
# C:\Users\akraj\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['No', 'Yes'],jitter=False)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = 'day', y = 'tip', kind = 'box', data = tips, hue = 'sex')

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = False)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = tips, dodge = False)

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = True,)

# %%
# kind : str, optional
#     The kind of plot to draw, corresponds to the name of a categorical
#     axes-level plotting function. Options are: "strip", "swarm", "box", "violin",
#     "boxen", "point", "bar", or "count".

# %%
g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)

sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)

# %%
titanic.head()

# %%
sns.catplot(x = 'deck', kind = 'count', palette = 'ch:0.95', data = titanic, hue = 'class')

# %% [markdown]
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()

# %%
from numpy.random import *
x = randn(1000)
x
# Out:
# array([-1.18424276e+00,  2.34607470e+00, -1.36283684e+00,  1.01445982e+00,
#        -1.58787517e+00,  1.69472411e-01, -1.19235154e+00, -1.58470620e+00,
#         1.17098424e+00, -3.72933898e-01,  2.85823698e-01,  5.18173965e-01,
#        -3.95521234e-01, -9.53545314e-01, -5.59845720e-01,  6.64715185e-01,
#         3.77950176e-01,  1.68276032e+00,  1.31187575e-01, -7.50186062e-01,
#        -4.44685271e-01,  1.22317476e+00,  4.89855455e-01, -3.64331359e-01,
#        -8.13001108e-01,  1.34278173e+00,  5.88043334e-01, -1.43447116e+00,
#        -1.08401927e+00,  3.55595001e-01, -2.69719985e-02,  2.37483995e-01,
#         2.47883464e-01, -7.97569641e-01, -1.03853966e-01,  2.70601293e-01,
#        -4.17185549e-01, -6.96794928e-01,  3.28824552e-01, -3.16378621e-01,
#        -1.52391232e+00,  2.21860301e-01,  1.12652613e+00,  1.11915955e+00,
#        -1.20961662e+00,  4.30270137e-01,  8.56970294e-01,  1.00921416e+00,
#        -1.87818589e-01,  1.42674814e+00, -2.36676859e-01,  8.68406647e-01,
#         7.80831932e-01,  1.05320270e+00, -1.09014079e+00,  6.17337219e-01,
#        -1.18603753e+00, -4.56999129e-02,  9.68523772e-01, -1.50217047e+00,
#         1.03228185e+00, -2.46424560e-01, -1.31555748e-01,  1.60615207e-02,
#        -8.43751385e-01, -9.30894988e-01,  5.07019057e-01, -5.02655777e-01,
#        -2.37497646e+00,  1.91619048e+00, -8.14681979e-02,  7.66191033e-01,
#         1.63289171e+00, -1.33513922e+00,  1.02696876e+00,  7.21397596e-01,
#        -1.60242056e+00, -1.64491028e-01,  1.42396912e-01,  1.71269137e+00,
#        -1.18836939e+00, -5.51864056e-01,  6.44337518e-01, -5.33500182e-01,
#        -6.61271453e-01, -5.37002303e-01, -6.15530448e-01,  8.30654736e-01,
#        -1.10525881e+00, -2.76679411e-01, -7.01223973e-01, -8.64189831e-01,
#        -8.95116152e-01,  2.17051677e-02, -8.70645139e-01,  1.96052037e-01,
#         6.02333612e-01,  5.85549190e-01,  1.64347908e+00, -5.87104045e-01,
#        -1.51218831e+00,  1.32985270e+00, -1.97347859e-01,  1.34991808e-01,
#        -6.04798947e-01,  1.88486217e-01,  7.51907652e-01, -1.65902214e+00,
#         6.93658734e-01,  1.93078570e+00, -4.31517041e-01, -3.95916857e-01,
#         8.67775574e-01,  5.52613905e-01,  7.14590854e-01, -1.35065421e+00,
#         2.35710752e-01, -3.86441959e-01, -8.59646863e-01, -4.31077404e-01,
#         5.94616421e-01, -9.88988940e-01, -1.25103884e+00,  1.50374205e+00,
#         1.76370617e-01,  8.02420768e-02, -2.80812128e-02, -1.17352312e+00,
#        -2.15816823e-01, -1.06392011e+00,  3.78815229e-01, -7.45752149e-01,
#        -4.34421906e-01, -5.21068259e-01,  3.89977234e-01,  1.00577894e+00,
#         5.23377088e-01, -2.53460889e-01,  9.70035052e-01,  5.68367236e-01,
#        -5.79933155e-01,  4.36822299e-01,  1.96503829e+00, -5.71361520e-02,
#         7.68741638e-01, -1.01511985e+00,  8.02411656e-01, -2.16253621e-02,
#        -2.70689623e-01, -1.22838112e+00, -1.70427346e+00, -1.66221704e+00,
#        -8.93215970e-01,  1.51727053e+00,  6.33021832e-01,  1.05238297e-01,
#         1.76340298e-01,  8.32529369e-01, -4.29006175e-01, -2.78472974e-01,
#        -1.33108517e+00,  2.39786193e+00, -6.40143544e-01, -2.96327135e-01,
#         5.13764872e-01,  1.75217971e-01, -1.27110282e+00,  7.82617875e-01,
#         1.21956902e+00,  6.88187896e-01, -2.85374651e+00, -1.29215248e-01,
#        -1.19774449e-01, -2.35941116e-01,  4.81120914e-01, -1.39430366e+00,
#        -3.45164963e+00, -1.34073880e-01,  9.06308829e-01,  3.37352648e-01,
#         1.20988708e+00,  8.56586917e-01,  1.65463214e+00, -8.11485413e-01,
#         5.82929630e-01,  1.31030308e+00, -6.89679614e-02, -3.74807494e-01,
#        -1.01424318e+00, -5.35698098e-01, -7.91123420e-01,  6.80188629e-01,
#        -1.56332302e+00, -2.11732568e+00,  6.84659126e-01, -1.90890184e+00,
#        -7.94572306e-01, -4.94941987e-02, -8.56932775e-01, -7.05751816e-01,
#         1.27164825e+00, -5.68780017e-01, -6.00104671e-01,  1.68137670e+00,
#         3.28108220e-01, -1.00596941e+00, -1.10722734e+00, -3.55635637e+00,
#        -1.01583936e+00, -5.21670317e-01,  6.09270074e-01, -7.79343109e-02,
#        -2.04486796e-01, -4.21180463e-01, -9.51622066e-01,  3.20977257e-01,
#         4.45315922e-01, -5.74313435e-01, -4.54427911e-01, -1.05517395e+00,
#        -1.35452917e+00,  1.69566939e-01,  7.34159254e-01,  1.83978665e+00,
#         4.43016109e-01, -1.42936981e+00,  8.41007041e-02,  6.27371111e-01,
#         2.44681176e-01, -8.74389530e-01,  1.93234874e+00,  3.78772285e-01,
#         9.41516132e-01, -9.93884931e-01, -4.95346169e-01, -5.55588128e-01,
#         1.23908845e+00, -2.57400773e-01, -8.62745932e-02,  1.01966627e-01,
#        -2.02341442e-01, -9.03103458e-01,  1.35029729e+00, -6.27671064e-01,
#         9.76232378e-01, -1.46898307e+00, -1.05628165e-01,  9.43505696e-03,
#        -4.09095908e-01,  2.24944557e+00,  2.13187627e+00, -1.30626923e+00,
#         2.71580814e-02,  8.27194876e-01,  1.11028987e+00, -3.59543236e-01,
#         4.77901388e-02,  1.31303383e+00,  1.46647582e-01,  6.55665508e-01,
#        -1.88436674e-01,  8.97930299e-01, -1.62951089e+00, -8.31632750e-01,
#         6.24766771e-02,  1.45586487e+00,  6.03336198e-01, -3.46400139e-02,
#        -3.75496268e-01,  3.80690764e-01, -9.34883843e-01,  8.16470975e-01,
#         1.94218436e+00, -4.39474603e-01,  8.95808893e-01,  3.99568022e-01,
#         5.41424335e-01,  7.73291052e-01, -5.44775334e-01,  1.11483646e+00,
#        -1.58288297e+00,  1.11066800e-01, -2.80461575e+00,  4.87850640e-01,
#         1.30309142e+00, -7.05953137e-01,  1.49146144e+00, -2.40838097e-01,
#         1.01057494e+00, -4.23358809e-02, -1.36113660e+00,  1.31941762e+00,
#        -1.07839275e-01, -1.89855081e+00,  1.55152733e+00, -6.40603696e-01,
#        -4.51417749e-01, -9.95768776e-01, -4.15646890e-01, -1.01808040e+00,
#         5.82041982e-02, -6.73973541e-01, -2.00532810e+00,  8.01892640e-01,
#        -1.62837876e-01, -1.73518750e+00, -1.49641746e+00,  1.74589046e-01,
#         4.08223235e-01, -9.46115346e-01, -1.55332560e+00,  1.87579335e-01,
#        -1.84969730e+00,  3.36717958e-01, -1.07190263e+00, -2.71215557e-01,
#         3.45099384e-01,  1.73456138e+00,  9.40793489e-01, -2.53452172e-01,
#        -6.11537225e-01,  6.73800746e-01, -2.65747212e-01,  1.52285698e+00,
#        -1.60959732e+00,  3.73804208e-01,  2.90075986e-01, -1.77106285e-01,
#         1.52869023e+00, -1.63223779e-01, -1.20248900e+00, -8.44170507e-01,
#         1.06948059e+00,  4.50132698e-01,  1.71386474e+00,  1.55085900e-01,
#         9.19437068e-01,  2.32823229e-01,  2.71077981e-01, -6.64258484e-01,
#         1.45035516e+00, -2.76149768e-01, -2.13716152e+00, -1.65552809e+00,
#        -6.75952358e-02, -2.17465729e-01, -5.33309801e-01, -5.54698345e-01,
#        -2.05740768e-01,  2.25912164e-01,  1.52846209e-01, -1.54625965e+00,
#         2.77337307e-01,  1.01995558e+00,  1.66000512e-01, -1.58738367e+00,
#         3.65093058e-01,  1.69178527e-01,  1.16472048e-01,  9.73675983e-01,
#        -5.84903810e-01,  1.44617409e+00,  1.85002919e-01,  2.97127967e-01,
#         8.25982413e-01,  7.62807808e-01,  1.59057719e+00, -1.79963606e+00,
#         6.53531429e-01,  2.43508638e-01, -1.75015897e+00,  8.34900745e-01,
#        -1.59126665e+00,  3.24908820e-01,  1.17239167e+00, -1.33695429e+00,
#        -5.05254443e-01,  2.41827602e+00,  3.25172257e-01, -1.21794956e+00,
#         1.65744874e+00, -2.09964363e+00, -1.06728202e+00, -3.77508064e-01,
#         2.54029435e-01,  1.05830574e+00, -6.62081728e-01, -5.72825510e-01,
#         3.86125242e-01, -5.87757963e-01,  8.77625765e-02, -3.12293306e-01,
#        -6.40402757e-01, -7.77540596e-01, -5.42284810e-01,  6.54096774e-01,
#         3.64234779e-01,  3.78301856e-02,  4.41724843e-01,  8.46355781e-01,
#         6.54132503e-01,  1.34181480e-01, -2.95002515e-01, -1.79002334e+00,
#         1.77098254e+00,  5.64817558e-01, -8.29004913e-02, -2.94111568e-01,
#         3.22411536e-01,  1.59102761e-01,  2.82599971e-01,  6.14745085e-01,
#        -1.38217856e+00, -1.01590293e+00,  2.22263102e+00, -2.15900008e-02,
#        -6.03863438e-01, -6.01621055e-01, -6.68214102e-01,  1.89731579e-01,
#        -8.75595595e-02, -3.13063386e+00,  3.20649336e-01, -6.53327919e-01,
#         1.34878734e+00, -3.60217439e-01, -3.57167223e-01, -2.00524422e-01,
#        -4.62501783e-01, -5.61102718e-02,  8.47793419e-01,  1.51886341e-01,
#        -5.98985170e-01, -5.23904216e-02, -2.02955344e-01, -9.85450118e-01,
#        -9.61172203e-01, -3.06223910e-01,  3.15811691e-01,  6.06363419e-01,
#        -1.68442495e+00,  2.03634022e+00,  1.16114816e+00, -6.02769223e-01,
#        -1.44322700e+00,  1.28570997e+00,  2.65686873e-01, -2.24185767e-01,
#         4.58728732e-01, -9.84814719e-02, -3.23377745e-01, -1.13541724e+00,
#         1.45587027e+00,  2.51543788e-01,  2.73751404e-01,  1.63048989e-01,
#         3.00227410e-01,  3.17207994e-01, -1.39494309e+00, -7.27664089e-01,
#        -1.56388481e-01,  1.45764843e+00, -5.59326454e-01, -1.93263090e-01,
#        -2.91102620e-01, -1.88315340e+00,  9.39661593e-01,  3.93248637e-01,
#        -1.70643626e+00,  4.59838264e-01,  5.17798638e-02,  7.38176578e-01,
#         1.47168190e-01,  6.39717928e-01, -2.49428739e+00, -8.38982225e-01,
#        -1.28820328e-01,  7.67428031e-01,  1.06088792e+00, -1.70127906e+00,
#        -1.75498101e+00, -3.11437445e-01, -1.79045114e+00,  5.88453680e-01,
#        -4.51854175e-01,  7.21843387e-01, -1.27422863e+00, -1.25897069e+00,
#         3.87068938e-01,  3.08352078e-01, -1.51766718e+00, -1.56944472e-01,
#        -6.27366223e-01, -1.13380210e+00, -1.80325700e+00, -3.36515245e-01,
#        -3.07670729e-01,  2.18369859e+00,  4.46385123e-01, -2.44341433e+00,
#         5.41155690e-01,  1.32797207e+00, -5.19337280e-01, -1.94370455e-01,
#         3.46751213e-01, -4.34171403e-01,  1.03132321e+00,  1.76692445e+00,
#        -2.81710775e-01, -1.39603681e+00,  4.14180113e-01,  2.19228432e+00,
#         2.22892610e-01, -9.80214159e-01, -9.32042826e-02,  1.27094146e+00,
#        -4.22536977e-01, -6.30769659e-01,  2.09323803e+00,  5.66556824e-01,
#         1.11040969e+00,  3.77533127e-01, -3.81344990e-01, -3.65556125e-01,
#         7.68647825e-01,  5.11934599e-01, -1.48046787e+00, -1.10668573e-01,
#         1.31363558e+00, -2.02401746e+00,  7.16250266e-01,  2.20563197e-01,
#         9.73672402e-01, -3.11040464e-01, -9.42150278e-01,  5.29268354e-01,
#        -5.39305398e-01, -5.23002080e-01, -2.20763797e+00, -4.45489452e-01,
#        -1.27884380e+00,  2.35747268e-02,  1.82799092e-01, -1.54903681e+00,
#         2.07696782e+00, -2.97198905e-01, -4.15598470e-01,  4.81759887e-01,
#         1.41211021e+00, -4.27171164e-01,  1.60969829e+00,  1.72151787e+00,
#         1.25348963e+00, -5.37528823e-02,  6.30296513e-01, -7.72482227e-01,
#        -1.41860437e-01, -4.74824245e-01,  1.71896685e-01,  2.74405378e-01,
#        -4.56884068e-01, -5.17545014e-01,  1.61934943e+00,  1.38688777e+00,
#         8.16721388e-01,  1.53654682e+00, -7.54723951e-01, -1.12744218e-01,
#        -1.06790824e+00,  8.39690422e-01, -6.94440260e-01, -2.00126572e+00,
#         1.07422397e+00, -3.86521392e-01, -6.40728004e-01,  1.84831162e+00,
#         4.25309803e-01,  2.28740622e+00, -1.77393851e+00, -7.83686043e-02,
#        -1.15031755e+00, -9.43050505e-01,  2.15627052e+00,  1.28320682e+00,
#         1.06705618e+00, -1.45228351e+00, -6.25206802e-01,  1.09026744e+00,
#        -3.89975147e-01,  7.71537658e-01,  1.21947971e+00, -2.89222104e-01,
#         3.66927249e-01,  4.78792674e-01,  2.91987199e-01,  3.67880183e-01,
#         8.70442856e-01, -3.67950897e-01, -1.76095807e-03, -1.03678397e+00,
#         1.90629383e+00,  1.14299770e+00, -9.97890215e-01, -5.65170213e-01,
#         1.17621848e+00, -9.78190114e-01, -1.45566291e+00, -1.02614357e+00,
#        -8.22827356e-01,  6.28437927e-01, -1.17015122e-01, -1.66852489e-01,
#        -2.65982020e+00, -7.39246838e-01,  1.86091060e+00,  8.39287960e-02,
#        -1.93625888e+00,  1.02075244e+00, -3.79698787e-01,  1.71255741e+00,
#        -1.09913843e+00, -4.70067602e-01,  4.74663009e-02, -9.19973679e-01,
#         8.84349254e-01, -4.07882858e-01, -7.63645210e-01, -2.96289919e+00,
#        -1.71147781e+00, -1.30253221e-01, -2.53582296e-01, -1.35000630e+00,
#        -3.57976365e-01, -1.67315546e+00, -1.38263885e+00,  1.25259462e+00,
#         1.44189244e+00, -1.19250708e+00, -8.41251191e-01,  9.14422168e-01,
#        -7.60054723e-01,  5.27795217e-02, -6.64851853e-01, -1.38093799e-01,
#        -9.46449621e-01, -3.01534994e-01,  7.16612037e-01,  1.50847414e+00,
#         1.35738493e+00,  7.20380509e-01, -8.92781154e-01,  6.22290527e-01,
#         8.58805851e-02,  4.36592216e-01,  7.80350456e-01,  1.26440353e-01,
#         1.29906384e+00, -1.67092539e+00,  6.22388429e-01, -4.17868373e-01,
#        -6.04162605e-03,  1.41820456e+00,  7.02531051e-01, -2.55842811e-02,
#        -1.88750891e+00, -8.08808315e-01,  3.90144940e-01, -4.35463398e-02,
#         1.61714428e+00,  6.02944877e-01, -3.44791479e-03, -8.70891276e-01,
#        -1.91681459e-01, -1.06949827e+00, -1.48971431e+00, -4.40473052e-01,
#         4.89721718e-01,  1.27299648e+00, -7.39255157e-01, -9.40751533e-01,
#        -4.50458440e-01,  9.64880847e-02,  1.79266726e+00, -4.00739700e-01,
#         2.85147870e-02,  1.74552427e+00, -1.16836843e-02, -1.08224111e+00,
#         2.61606337e-01,  2.29329954e+00, -2.71237802e-01, -7.25387538e-04,
#        -2.29204030e-02,  6.57498270e-01,  1.00089861e+00,  1.45993350e+00,
#         6.22756338e-01, -9.80773859e-01, -5.88217543e-01, -8.69586220e-01,
#         1.59180356e+00,  2.59494368e+00,  1.19716969e+00,  2.83224529e-01,
#        -2.81364934e-01,  5.44647405e-01, -9.52100141e-01, -5.00704376e-01,
#        -6.76955814e-01, -7.87229719e-01, -1.54842353e-01,  1.67159178e+00,
#        -5.82691373e-01, -5.44484770e-01,  6.35695199e-03,  1.79072225e+00,
#        -4.94191178e-01,  5.28258351e-01,  1.26722751e+00,  2.94376067e-01,
#         4.76051211e-02, -6.13781124e-01, -7.64887290e-01, -3.79532043e-01,
#         1.95824444e+00,  8.98740270e-01, -1.73566306e+00,  1.01689715e+00,
#        -8.15478893e-01,  5.53762609e-01, -3.27796664e-01, -3.78328189e-01,
#        -8.03550253e-01,  3.76342437e-02, -6.82408743e-01,  6.45520535e-01,
#        -6.42754665e-01, -4.00782854e-01,  8.06742643e-01, -1.52160880e+00,
#         8.43581878e-03, -5.53898854e-01,  3.15702231e-01, -1.18308712e+00,
#        -9.88899887e-01, -1.06347558e+00, -8.03518925e-01, -9.39430416e-01,
#        -1.81359553e+00, -1.05112020e+00,  2.21571935e-01,  1.85997765e+00,
#         9.45958785e-02,  4.81445579e-01, -9.51230813e-01,  2.06298373e+00,
#         4.04463039e-01,  6.65744774e-01, -8.84570044e-01, -8.88914187e-01,
#        -2.22085516e-01,  1.62354543e-02, -1.54679085e+00, -5.69229087e-01,
#         3.58210809e-01, -1.22835089e+00,  5.94169836e-01,  1.44094962e+00,
#        -1.24767483e+00, -1.06207313e+00,  1.81476203e-01,  3.16528976e-01,
#        -3.01612213e-01,  3.39404015e-01,  2.23869602e-01,  1.42121882e+00,
#        -8.90031531e-01, -7.63889284e-01, -1.95398317e-01, -2.95874484e-02,
#         1.75657913e-01, -6.16801422e-01, -1.04674902e+00, -3.96647335e-01,
#         2.46774611e-02, -7.24223594e-01,  7.51941595e-02,  1.21939553e-01,
#        -9.95425386e-01,  6.07591034e-01, -3.06618378e+00, -1.38700381e-01,
#        -8.74928834e-02,  1.88420704e+00,  1.50969716e+00,  1.94632151e-02,
#         1.81428964e+00,  6.10504629e-01,  3.85453468e-01,  4.45436343e-01,
#         2.03214139e+00, -1.71680196e-01,  2.24950331e-02, -2.92301621e-01,
#        -6.78144567e-01,  9.78767654e-02, -3.56827393e-02,  1.42392834e+00,
#        -1.95041477e+00, -5.84972344e-01,  6.27441282e-01,  1.86138923e-01,
#         8.45076856e-01,  1.79744194e+00, -1.84884422e+00, -8.98427483e-01,
#        -1.32655835e+00, -8.52852421e-01,  1.38758379e-01,  4.06007716e-03,
#        -1.58487103e-01,  1.30955908e+00,  1.19631246e+00,  1.26925860e+00,
#         2.37684636e-01,  1.54472367e+00,  1.30436390e-01, -1.69281929e+00,
#         2.07686259e+00,  7.05564603e-01,  4.33426597e-01, -1.75378920e-01,
#        -1.70223739e-01,  1.32412470e+00,  6.78886158e-01, -1.10854372e+00,
#        -4.08017908e-01, -4.75726110e-01,  6.49547475e-01, -7.29183411e-01,
#        -1.31047161e+00,  6.93525702e-01, -1.42961481e-01, -1.51115403e+00,
#         1.88649385e-01, -6.53146961e-01,  1.71408743e+00, -9.05666273e-01,
#         1.08019034e+00, -2.08204204e+00,  6.61512191e-01, -1.08970484e+00,
#        -5.34429309e-01,  3.66157974e-01, -6.49814609e-01, -1.77483855e+00,
#        -8.29339413e-01,  3.07143952e-01, -1.04140945e+00,  1.14376974e+00,
#         7.11371860e-01, -7.00390891e-01,  1.04700107e+00,  3.25954427e+00,
#         9.26823005e-01, -3.93582354e-01, -1.04703530e+00, -6.41343672e-02,
#        -1.18830760e+00,  1.35171775e+00,  1.24651429e+00, -1.75907776e+00,
#         9.67332375e-01, -1.08437963e+00,  5.54520534e-01,  3.98774502e-01,
#         1.91489348e-01, -1.01358818e-01,  7.18267245e-01,  4.79731328e-01,
#        -3.28814695e-01,  7.66403187e-02, -6.88038119e-01,  1.21013743e+00,
#         2.05972474e-01,  1.74758152e-02, -2.09856707e+00,  3.14995267e-01,
#        -1.25675790e+00,  6.13254058e-01, -1.02192655e+00, -1.04487988e+00,
#        -1.05754013e+00,  5.04524822e-01,  1.46199991e+00, -1.29209557e+00,
#        -3.61052900e-01,  1.29026790e+00,  5.94134397e-01, -1.27389168e+00,
#         1.23505351e-01,  8.11513049e-01,  1.11976755e-01,  1.42388637e+00,
#         4.71470384e-01, -1.02065013e+00, -9.88773960e-01, -5.34575521e-02,
#         5.17996920e-02, -7.50633106e-01, -1.79347586e+00, -1.10042303e+00,
#        -1.69372207e+00,  4.84681301e-01,  1.35449180e+00, -1.21100956e-01,
#         7.31501859e-01,  2.18831874e+00, -3.53225389e-01, -1.23946459e+00,
#         9.91797039e-01, -1.23680684e+00, -2.17346279e+00,  4.16363254e-01,
#         5.64686937e-01, -3.11506628e-01, -6.31465004e-01,  1.59862713e+00,
#         2.28427480e+00, -5.19024296e-01, -2.46517868e-01, -9.00464863e-01,
#         4.29511675e-01,  1.97764320e-01,  2.71461375e+00, -9.13809419e-02,
#        -3.21211566e-01,  1.26536970e-01,  4.79496735e-01,  1.21336234e-01,
#         1.23721571e+00,  5.82638559e-01,  6.81315499e-01, -1.29731257e+00,
#         8.47778625e-01, -5.96442930e-01,  3.37738587e-01, -1.12821379e+00,
#         1.18278375e+00, -6.76064917e-01, -6.09499209e-01, -1.45400367e+00,
#         2.86251693e-01,  1.39328699e+00, -1.63667344e-01, -8.55930883e-01,
#         1.44532825e+00, -1.19860986e+00,  2.13737890e+00, -6.16928091e-01,
#        -9.28759296e-01,  4.72918259e-01, -4.65380424e-01, -1.99944216e+00,
#         1.19899874e+00,  5.40369386e-01, -1.19424250e+00, -9.86184881e-02,
#         5.25747348e-02, -8.78704558e-01,  6.44277514e-03, -2.02263111e-01,
#         5.29103978e-01,  2.14769973e+00,  4.23955534e-01,  1.68321199e+00,
#         7.69487454e-01, -2.81555616e-02, -4.03662592e-01,  1.55195785e+00,
#        -7.17801757e-01,  2.13062557e-01, -3.79478471e-01, -3.34222557e-01,
#        -2.63334827e+00,  7.15694403e-01, -1.63398513e-01,  8.76578553e-01,
#        -1.63889840e+00,  1.50392801e+00, -1.18164500e+00, -8.60312835e-02,
#         9.73465820e-01,  2.96732442e-01, -3.34062832e-01,  8.99576858e-01,
#        -9.15451183e-01, -1.49648945e+00,  1.25360444e+00, -8.44697479e-01])

# %%
# import numpy.random
# dir(numpy.random)

# %%
sns.distplot(x, kde = True, hist = True, rug= False, bins= 30)
# Out:
# C:\Users\akraj\AppData\Local\Temp\ipykernel_9400\609003487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde = True, hist = True, rug= False, bins= 30)
# <Axes: ylabel='Density'>

# %%
tips = sns.load_dataset('tips')
tips.head()

# %%
x = tips['total_bill']
y = tips['tip']

# %%
x

# %%
sns.jointplot(x = x, y=y)

# %%
sns.set()
sns.jointplot(x = x, y=y, kind = 'hex')

# %%
sns.jointplot(x = x, y = y, kind = 'kde')

# %%
f, ax = plt.subplots(figsize = (6,6))

cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)

sns.kdeplot(x, y, cmap = cmap, n_levels=60, shade=True)

# %%
g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g.plot_joint(plt.scatter, c = 'w', s = 30, linewidth = 1, marker = '+')
g.ax_joint.collections[0].set_alpha(0)

# %%
iris= sns.load_dataset('iris')

iris

# %%
iris= sns.load_dataset('iris')
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %% [markdown]
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips)

# %%
data = sns.load_dataset('anscombe')
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
data['dataset'].value_counts()
# Out:
# dataset
# I      11
# II     11
# III    11
# IV     11
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize = (8,4))
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax)
ax
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', col_wrap=2, height = 4)

# %% [markdown]
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
np.linspace(0, 14, 100)
# Out:
# array([ 0.        ,  0.14141414,  0.28282828,  0.42424242,  0.56565657,
#         0.70707071,  0.84848485,  0.98989899,  1.13131313,  1.27272727,
#         1.41414141,  1.55555556,  1.6969697 ,  1.83838384,  1.97979798,
#         2.12121212,  2.26262626,  2.4040404 ,  2.54545455,  2.68686869,
#         2.82828283,  2.96969697,  3.11111111,  3.25252525,  3.39393939,
#         3.53535354,  3.67676768,  3.81818182,  3.95959596,  4.1010101 ,
#         4.24242424,  4.38383838,  4.52525253,  4.66666667,  4.80808081,
#         4.94949495,  5.09090909,  5.23232323,  5.37373737,  5.51515152,
#         5.65656566,  5.7979798 ,  5.93939394,  6.08080808,  6.22222222,
#         6.36363636,  6.50505051,  6.64646465,  6.78787879,  6.92929293,
#         7.07070707,  7.21212121,  7.35353535,  7.49494949,  7.63636364,
#         7.77777778,  7.91919192,  8.06060606,  8.2020202 ,  8.34343434,
#         8.48484848,  8.62626263,  8.76767677,  8.90909091,  9.05050505,
#         9.19191919,  9.33333333,  9.47474747,  9.61616162,  9.75757576,
#         9.8989899 , 10.04040404, 10.18181818, 10.32323232, 10.46464646,
#        10.60606061, 10.74747475, 10.88888889, 11.03030303, 11.17171717,
#        11.31313131, 11.45454545, 11.5959596 , 11.73737374, 11.87878788,
#        12.02020202, 12.16161616, 12.3030303 , 12.44444444, 12.58585859,
#        12.72727273, 12.86868687, 13.01010101, 13.15151515, 13.29292929,
#        13.43434343, 13.57575758, 13.71717172, 13.85858586, 14.        ])

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x+i*0.5)*(7-i))

# %%
sinplot()

# %%
sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in'})

sinplot()
sns.despine(left = True, bottom= False)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'in',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid')

# %%
sns.set_context('talk', font_scale=1.5)
sinplot()

# %%
current_palettes = sns.color_palette()
sns.palplot(current_palettes)

# %%
sns.palplot(sns.color_palette('hls', 8))
